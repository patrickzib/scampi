# %%
# %load_ext autoreload
# %autoreload 2

# import os
# import glob
import sys
sys.path.insert(0, "../")

# import numpy as np
import pandas as pd
# import seaborn as sns
from aeon.visualisation import plot_critical_difference

import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import warnings
warnings.simplefilter("ignore")

pd.set_option('display.precision', 1)

# %%
df = pd.read_csv("../tests/results/results_tsmd-fscore.csv")
df.set_index("dataset", inplace=True)
df.fillna(0,inplace=True)
df
# Out:
#                  MOMP  LoCoMotif       LM  k-Motiflets  VALMOD  SetFinder  \
# dataset
# arm-coda      2.5e-01        0.2  2.7e-01      7.3e-02     0.3        0.2
# mitdb         5.0e-01        0.1  2.9e-01      4.6e-01     0.2        0.6
# mitdb1        6.3e-01        0.3  1.4e-01      7.3e-01     0.7        0.8
# ptt-ppg       4.9e-01        0.4  2.7e-01      6.1e-01     0.5        0.7
# JIGSAWMaster  2.6e-01        0.3  2.6e-01      1.5e-01     0.2        0.2
# JIGSAWSlave   2.5e-01        0.3  2.4e-01      1.1e-01     0.2        0.2
# REFIT         0.0e+00        0.0  3.0e-02      1.6e-01     0.0        0.0
# SIGN          6.0e-02        0.0  1.4e-01      7.0e-02     0.0        0.0
#
#               A-PEPA  GrammarViz  SCAMPI
# dataset
# arm-coda         0.3     1.0e-02     0.3
# mitdb            0.5     0.0e+00     0.5
# mitdb1           0.4     0.0e+00     0.7
# ptt-ppg          0.4     0.0e+00     0.6
# JIGSAWMaster     0.2     1.0e-01     0.3
# ...

# %%
ax = plot_critical_difference(
    scores=df.to_numpy(),
    labels=df.columns.to_numpy(),    
    alpha=0.05,
    width=8
)
plt.tight_layout()
plt.savefig("images/tsmd_all.pdf", bbox_inches='tight')

# %%
ax = plot_critical_difference(
    scores=df.iloc[:-2].to_numpy(),
    labels=df.columns.to_numpy(),    
    alpha=0.05,
)
#plt.tight_layout()
plt.savefig("images/tsmd_first.pdf", bbox_inches='tight')
