# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "../")

from scampi.scampi import *
from scampi.plotting import *
import tests.utils as ut

import pandas as pd

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import warnings
warnings.simplefilter("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using directory: ../datasets/momp/ True

# %%
data = ut.read_mat("FingerFlexionECoG")
# Out:
# 	Reading FingerFlexionECoG from ../datasets/momp/FingerFlexionECoG.mat
# 	Length: 23999997 183.11 MB

# %%
smp = SCAMPI("Finger Flexion", data)
smp.plot_dataset(path="finger_flexion.svg")
# plt.savefig("finger_flexion.svg")
# Out:
# (<Figure size 2000x500 with 1 Axes>,
#  array([[<Axes: title={'center': 'Finger Flexion'}>]], dtype=object))
