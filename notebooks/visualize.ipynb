# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.insert(0, "../")

from scampi.scampi import *
from scampi.plotting import *
import benchmarks.utils as ut

import pandas as pd

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

import warnings
warnings.simplefilter("ignore")

# %%
data = ut.read_mat("FingerFlexionECoG")
# Out:
#   Reading: /Users/bzcschae/workspace/scampi_paper/datasets/momp/FingerFlexionECoG.mat
#   Series: n=23999997 size=183.11MB

# %%
smp = SCAMPI("Finger Flexion", data)
fig, ax = smp.plot_dataset(path="finger_flexion.svg")
# plt.savefig("finger_flexion.svg")
